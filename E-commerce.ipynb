# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data= pd.read_csv("ecommerce_customer_data_custom_ratios.csv")
# Out:
# C:\Users\Venki\AppData\Local\Temp\ipykernel_7284\2947967273.py:1: DtypeWarning: Columns (1,2,6,9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv("ecommerce_customer_data_custom_ratios.csv")

# %%
data.head()
# Out:
#    Customer ID     Purchase Date Product Category  Product Price  Quantity  \
# 0      46251.0  08-09-2020 09:38      Electronics           12.0       3.0
# 1      46251.0  05-03-2022 12:56             Home          468.0       4.0
# 2      46251.0  23-05-2022 18:18             Home          288.0       2.0
# 3      46251.0  12-11-2020 13:13         Clothing          196.0       1.0
# 4      13593.0  27-11-2020 17:55             Home          449.0       1.0
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                  740.0    Credit Card          37.0      0.0
# 1                 2739.0         PayPal          37.0      0.0
# 2                 3196.0         PayPal          37.0      0.0
# 3                 3509.0         PayPal          37.0      0.0
# 4                 3452.0    Credit Card          49.0      0.0
#
#          Customer Name   Age  Gender  click_patterns
# 0  Christine Hernandez  37.0    Male             8.0
# 1  Christine Hernandez  37.0    Male             8.0
# 2  Christine Hernandez  37.0    Male            11.0
# 3  Christine Hernandez  37.0    Male             9.0
# 4          James Grant  49.0  Female            30.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer ID            199 non-null    float64
#  1   Purchase Date          199 non-null    object
#  2   Product Category       199 non-null    object
#  3   Product Price          199 non-null    float64
#  4   Quantity               199 non-null    float64
#  5   Total Purchase Amount  199 non-null    float64
#  6   Payment Method         199 non-null    object
#  7   Customer Age           199 non-null    float64
#  8   Returns                199 non-null    float64
#  9   Customer Name          199 non-null    object
#  10  Age                    199 non-null    float64
#  11  Gender                 199 non-null    object
#  12  click_patterns         199 non-null    float64
# dtypes: float64(8), object(5)
# memory usage: 24.8+ MB

# %%
category_counts = data['Product Category'].value_counts()

# %%
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar')
plt.title('Most Popular Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 8))
category_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Product Categories')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
